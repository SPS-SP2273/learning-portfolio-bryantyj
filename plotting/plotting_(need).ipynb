# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
# Your code here
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=1, label='Y values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) #how visible the lines are
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ### 1.2 Adding another plot

# %%
# Your code here

# %%
plt.plot(x, y_1, color='blue', label='Y2 values')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
# Your code here

# %%
y_3 = [0, 4, 8, 12, 16, 20, 24]
plt.errorbar(x, y_3, xerr = x_error, yerr = y_error, 
             color = "green", label = "Y3 with errors")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             color='green', label='Y3 with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y', color = 'red')
plt.grid(alpha=.25, color = 'red', linestyle = 'dashed')
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %%
# Your code here
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3,  xerr=x_error, yerr=y_error,
             color='green', label='Y3 with errors')
plt.xlabel('x-values')
plt.ylabel('y-values' , color='green')
plt.title('X vs Y', color = 'red')
plt.grid(alpha=.25, color = 'red', linestyle = 'dashed')
plt.legend(loc='lower center')
plt.show()

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
# Your code here

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
# Your code here

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.7 We need another axis!

# %%
# Your code here
b

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### 1.8 Saving to disc

# %%
# Your code here

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150) #now its in the folder in my notebook in plotting

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
# Your code here

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# %% [markdown]
# ### 2.2 xkcd!

# %%
# Your code here

# %%
#need to ownself import the font files to work
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
# Your solution here
plt.style.use('default')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, xerr=x_err, yerr=y_err,
             color='maroon', linestyle='dashed',
             marker='o', markerfacecolor='yellow',      #marker = marker of crosshair, need to search specific type
             ecolor='black',capsize=5,                  #ecolor = crosshair color
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
#save_file_figure(plt, argv)                  # Hide
plt.show(block=False)                         # ?

# %%
# Your solution here

# %%
import numpy as np

    
x=[]
y=[]

for i in range (51):
    x.append(i) 
x=np.linspace(0,51,1000)
for j in x: 
    output=np.exp(-(j/10))*np.sin(j)
    y.append(output)
    
plt.plot(x, y, color='cornflowerblue')
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15, rotation=0)
plt.ylim(-1,1)
plt.title(r'$y=e^{-x/10}sin(x)$', fontsize=20)
plt.grid(alpha=.25)
plt.tick_params(axis='x', color= 'darkblue')    #colors=number only, color=axis dashes+number
plt.tick_params(axis='y', color= 'darkblue')

# %%
import numpy as np

    
x= np.array([d for d in range(51)])
x= np.linspace(0,51,1000)
y= np.array(np.exp(-(x/10))*np.sin(x))


plt.plot(x, y, color='cornflowerblue')
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15, rotation=0)
plt.ylim(-1,1)
plt.title(r'$y=e^{-x/10}sin(x)$', fontsize=20)
plt.grid(alpha=.25)
plt.tick_params(axis='x', color= 'darkblue')    #colors=number only, color=axis dashes+number
plt.tick_params(axis='y', color= 'darkblue')
